# %% [markdown]
# <a href="https://colab.research.google.com/github/Emadamx/meminject/blob/main/meminject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf meminject

# %%
# !git clone https://github.com/Emadamx/meminject.git
# Out:
# Cloning into 'meminject'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 46 (delta 5), reused 46 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (46/46), 21.94 KiB | 7.31 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# %cd meminject
# Out:
# /content/meminject

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/meminject
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for meminject
# ...

# %%
# %run examples/basic_injection.py
# Out:
# [05:26:30] INFO meminject.pipeline — [Turn 0] Injecting adversarial memory...
# INFO:meminject.pipeline:[Turn 0] Injecting adversarial memory...
# [05:26:30] INFO meminject.pipeline — [Turn 0] ✓  clean
# INFO:meminject.pipeline:[Turn 0] ✓  clean
# [05:26:30] INFO meminject.pipeline — [Turn 1] ✓  clean
# INFO:meminject.pipeline:[Turn 1] ✓  clean
# [05:26:30] INFO meminject.pipeline — [Turn 2] ⚠️  TRIGGERED
# INFO:meminject.pipeline:[Turn 2] ⚠️  TRIGGERED
# [05:26:30] INFO meminject.pipeline — [Turn 3] ⚠️  TRIGGERED
# INFO:meminject.pipeline:[Turn 3] ⚠️  TRIGGERED
# [05:26:30] INFO meminject.pipeline — [Turn 4] ⚠️  TRIGGERED
# INFO:meminject.pipeline:[Turn 4] ⚠️  TRIGGERED
# [05:26:30] INFO meminject.pipeline — [Turn 5] ⚠️  TRIGGERED
# INFO:meminject.pipeline:[Turn 5] ⚠️  TRIGGERED
# [05:26:30] INFO meminject.pipeline — [Turn 6] ⚠️  TRIGGERED
# INFO:meminject.pipeline:[Turn 6] ⚠️  TRIGGERED
# [05:26:30] INFO meminject.pipeline — [Turn 7] ⚠️  TRIGGERED
# ...
